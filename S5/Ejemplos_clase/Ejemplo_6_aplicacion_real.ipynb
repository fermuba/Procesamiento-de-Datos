# %% [markdown]
# <a href="https://colab.research.google.com/github/fermuba/Procesamiento-de-Datos/blob/main/S5/Ejemplos_clase/Ejemplo_6_aplicacion_real.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ejemplo 6: Limpiando NaNs en un dataset real
#
# ### 1. Objetivos:
#     - Aplicar lo aprendido hasta ahora en un dataset real
#
# ---
#
# ### 2. Desarrollo:

# %%
# Cargamos librerias
import pandas as pd

# %%
# Cargamos modulo de permiso para lectura de archivos dentro de nuestro Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Para leer un archivo .csv en `pandas`, usamos `read_csv` y le indicamos que el separador (el signo que delimita las columnas en el archivo .csv) es una coma:

# %%
df = pd.read_csv('/content/drive/MyDrive/BEDU/ProcesamientoDatos/Datasets/melbourne_housing-raw.csv', sep=',')

df
# Out:
#            Suburb               Address  Rooms Type      Price Method  \
# 0      Abbotsford         68 Studley St      2    h        NaN     SS
# 1      Abbotsford          85 Turner St      2    h  1480000.0      S
# 2      Abbotsford       25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford    18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford          5 Charles St      3    h  1465000.0     SP
# ...           ...                   ...    ...  ...        ...    ...
# 19735     Windsor       201/152 Peel St      2    u   560000.0     PI
# 19736     Wollert       60 Saltlake Bvd      3    h   525300.0      S
# 19737  Yarraville           2 Adeney St      2    h   750000.0     SP
# 19738  Yarraville       54 Pentland Pde      6    h  2450000.0     VB
# 19739  Yarraville  10/127 Somerville Rd      3    t   645000.0     SP
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %% [markdown]
# ### Diccionario
#
# - Suburb: Nombre del suburbio donde se encuentra la propiedad.
# - Address: Dirección específica de la propiedad.
# - Rooms: Número de habitaciones en la propiedad.
# - Type: Tipo de propiedad. Generalmente, esto puede incluir categorías como:
#     + 'h' para casa (house)
#     + 'u' para unidad (unit)
#     + 't' para townhouse (casa adosada)
# - Price: Precio de venta de la propiedad.
# - Method: Método de venta. Algunos ejemplos comunes incluyen:
#     + 'S' para venta estándar
#     + 'SP' para venta con precio
#     + 'PI' para venta antes de la subasta
#     + 'VB' para ventas de oferta y negociación
#     + 'SA' para ventas después de la subasta
# - SellerG: Nombre del agente o agencia inmobiliaria que vende la propiedad.
# - Date: Fecha de la venta de la propiedad.
# - Distance: Distancia de la propiedad al centro de la ciudad (en kilómetros).
# - Postcode: Código postal donde se encuentra la propiedad.
# - Bedroom2: Número de dormitorios secundarios en la propiedad (puede ser redundante con 'Rooms' en algunos casos).
# - Bathroom: Número de baños en la propiedad.
# - Car: Capacidad de estacionamiento de la propiedad (número de coches que se pueden estacionar).
# - Landsize: Tamaño del terreno en metros cuadrados.
# - BuildingArea: Área construida en metros cuadrados.
# - YearBuilt: Año de construcción de la propiedad.
# - CouncilArea: Área del consejo municipal en la que se encuentra la propiedad.
# - Lattitude: Latitud geográfica de la propiedad.
# - Longtitude: Longitud geográfica de la propiedad.
# - Regionname: Nombre de la región o zona en la que se encuentra el suburbio.
# - Propertycount: Número total de propiedades en el suburbio.

# %%
# Tamaño
df.shape
# Out:
# (19740, 21)

# %%
# Primeros elementos
df.head(5)
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
# Calculamos NaN por cada columna
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             4344
# Method               0
# SellerG              0
# Date                 0
# Distance             8
# Postcode             8
# Bedroom2          4413
# Bathroom          4413
# Car               4413
# Landsize          4796
# BuildingArea     11123
# YearBuilt        10389
# CouncilArea       4444
# Lattitude         4292
# Longtitude        4292
# Regionname           8
# Propertycount        8
# dtype: int64

# %% [markdown]
# Hay demasiados `NaNs` en las columnas 'BuildingArea' y 'YearBuilt', así que vamos a deshacernos de esas columnas:

# %%
# Eliminamos las 2 columnas 'BuildingArea', 'YearBuilt' y asignamos el resultado a df_2
df_2 = df.drop(columns=['BuildingArea', 'YearBuilt'])

df_2.isna().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price            4344
# Method              0
# SellerG             0
# Date                0
# Distance            8
# Postcode            8
# Bedroom2         4413
# Bathroom         4413
# Car              4413
# Landsize         4796
# CouncilArea      4444
# Lattitude        4292
# Longtitude       4292
# Regionname          8
# Propertycount       8
# dtype: int64

# %% [markdown]
# Llenemos los `NaNs` en Regionname con la palabra `Unknown`:

# %%
# Cuando tenemos NaN y no los necesitamos pero si el resto de la fila,
# es una buena practica completarlos, en este caso 'Unknown'
df_2['Regionname'] = df_2['Regionname'].fillna('Unknown')

df_2.isna().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price            4344
# Method              0
# SellerG             0
# Date                0
# Distance            8
# Postcode            8
# Bedroom2         4413
# Bathroom         4413
# Car              4413
# Landsize         4796
# CouncilArea      4444
# Lattitude        4292
# Longtitude       4292
# Regionname          0
# Propertycount       8
# dtype: int64

# %% [markdown]
# Ahora eliminemos las filas que contengan al menos un `NaN`:

# %%
# Ahora con el trabajo previo, ya podemos eliminar las filas restantes, porque no las necesitamos
# Las asignamos a un nuevo dataframe df_dropped
df_dropped = df_2.dropna(axis=0, how='any')

df_dropped.isna().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %% [markdown]
# Éste es el número de columnas con el que nos quedamos:

# %%
# Tamaño del Dataframe limpio
df_dropped.shape
# Out:
# (11646, 19)

# %%
# Info gral
df_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11646 entries, 1 to 19739
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         11646 non-null  object
#  1   Address        11646 non-null  object
#  2   Rooms          11646 non-null  int64
#  3   Type           11646 non-null  object
#  4   Price          11646 non-null  float64
#  5   Method         11646 non-null  object
#  6   SellerG        11646 non-null  object
#  7   Date           11646 non-null  object
#  8   Distance       11646 non-null  float64
#  9   Postcode       11646 non-null  float64
#  10  Bedroom2       11646 non-null  float64
#  11  Bathroom       11646 non-null  float64
#  12  Car            11646 non-null  float64
#  13  Landsize       11646 non-null  float64
#  14  CouncilArea    11646 non-null  object
#  15  Lattitude      11646 non-null  float64
#  16  Longtitude     11646 non-null  float64
# ...

# %%
# Info complementaria
df_dropped.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  11646.000000  1.164600e+04  11646.000000  11646.000000  11646.000000
# mean       2.885025  1.068142e+06      9.583059   3102.080543      2.859437
# std        0.958165  6.437282e+05      5.304187     84.043125      0.971155
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.400000e+05      5.900000   3044.000000      2.000000
# 50%        3.000000  8.955000e+05      9.100000   3083.000000      3.000000
# 75%        3.000000  1.325000e+06     12.300000   3146.000000      3.000000
# max        8.000000  9.000000e+06     47.400000   3977.000000     20.000000
#
#            Bathroom           Car      Landsize     Lattitude    Longtitude  \
# count  11646.000000  11646.000000  11646.000000  11646.000000  11646.000000
# mean       1.514855      1.564743    554.458097    -37.809574    144.992541
# ...

# %% [markdown]
# Guardemos el resultado:

# %%
# Guardamos a un archivo .csv -- Corregir PATH !!!
df_dropped.to_csv('../../Datasets/melbourne_housing-no_nans.csv')

# %% [markdown]
# Seguiremos trabajando este dataset en el último ejemplo.
